# %% [markdown]
# ## Linear Regression Inner Process from Scratch

# %%
# import all necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the data-set
dataset = pd.read_csv("score.csv")
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# lets plot this in graph
plt.scatter(x = dataset["Hours"], y = dataset["Scores"])
plt.title("Study Hours vs Scores")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()

# %%
x = [1, 8]
y = [1, 8]
plt.plot(x, y, c = 'r')
plt.show()
