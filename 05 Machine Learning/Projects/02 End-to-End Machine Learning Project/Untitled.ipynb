# %% [markdown]
# # End-to-End Machine Learning Project

# %% [markdown]
# An End-to-End Machine Learning Project means completing all the steps involved in a machine learning workflow, from the beginning to the end. Here's a breakdown of what it typically includes:
# 1) Problem Definition: Understanding the problem you're trying to solve (e.g., classification, regression, etc.).
# 2) Data Collection: Gathering relevant data that will help solve the problem.
# 3) Data Preprocessing: Cleaning and preparing the data (e.g., handling missing values, normalization, feature engineering).
# 4) Model Selection: Choosing an appropriate machine learning model to use (e.g., decision trees, linear regression).
# 5) Model Training: Using the training data to teach the model how to make predictions.
# 6) Model Evaluation: Testing how well the model performs on new, unseen data (using metrics like accuracy, precision, etc.).
# 7) Tuning and Optimization: Adjusting model parameters or features to improve performance.
# 8) Deployment: Putting the model into production so it can start making real-world predictions.
# 9) Monitoring and Maintenance: Continuously tracking the model's performance and updating it when necessary (e.g., retraining with new data).

# %% [markdown]
# ###### Download the Data
# ```
# Create file paths (pathlib).
# Download a compressed file (urllib.request).
# Extract the contents of the compressed file (tarfile).
# Read the data from the extracted CSV file into a DataFrame (pandas).
# ```

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path = "datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

# %%
housing = load_housing_data()

# %% [markdown]
# ###### Take a Quick Look at the Data Structure

# %%
# view the first 5 rows of the dataset
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# view the information about dataset columns
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# see the total unique values in ocean_proximity with count
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# view the summury stats for numerical columns
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# lets plot and see the distribution of all numerical columns
import matplotlib.pyplot as plt

housing.hist(bins=50, figsize=(15, 8))
plt.show()

# %% [markdown]
# ######  Lets Create Test Set

# %%
import numpy as np

# lest split the dataset using numpy
def shuffle_and_split_data(data, test_ratio):
    np.random.seed(42) # using this can prevent the shuffle when re run the program
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = shuffle_and_split_data(housing, 0.2)
print(f"Train Set Size : {len(train_set)} \nTest Set Size : {len(test_set)}")
# Out:
# Train Set Size : 16512
# Test Set Size : 4128

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.22     32.75                34.0       6001.0          1111.0
# 8267     -117.03     32.69                10.0        901.0           163.0
# 17445    -122.27     37.74                28.0       6909.0          1554.0
# 14265    -121.82     37.25                25.0       4021.0           634.0
# 2271     -115.98     33.32                 8.0        240.0            46.0
# ...          ...       ...                 ...          ...             ...
# 11284    -122.37     37.94                49.0        969.0           229.0
# 11964    -118.38     33.89                35.0       1778.0           330.0
# 5390     -119.33     36.28                16.0       2624.0           527.0
# 860      -117.19     34.08                22.0       2467.0           555.0
# 15795    -118.86     34.22                22.0       1230.0           200.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -122.38     40.67                10.0       2281.0           444.0
# 3024     -118.37     33.83                35.0       1207.0           207.0
# 15663    -117.24     32.72                39.0       3089.0           431.0
# 20484    -118.44     34.05                18.0       4780.0          1192.0
# 9814     -118.44     34.18                33.0       2127.0           414.0
# ...          ...       ...                 ...          ...             ...
# 15362    -121.92     40.52                13.0       4581.0           881.0
# 16623    -122.08     37.68                26.0       2607.0           682.0
# 18086    -119.00     35.39                42.0       2839.0           516.0
# 2144     -117.92     33.63                39.0       1469.0           226.0
# 3665     -118.39     34.02                38.0       2447.0           636.0
#
# ...

# %%
# another way to split data
from zlib import crc32

# %%
# using stratified sampling create test and train sets, lets divide "median_income" column into 5 categories
housing["income_cat"] = pd.cut(housing["median_income"], 
                              bins=[0., 1.5, 3.0, 4.5, 6.0, np.inf], 
                              labels=[1, 2, 3, 4, 5])
print(housing["income_cat"])
# Out:
# 0        5
# 1        5
# 2        5
# 3        4
# 4        3
#         ..
# 20635    2
# 20636    2
# 20637    2
# 20638    2
# 20639    2
# Name: income_cat, Length: 20640, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
housing["income_cat"].value_counts().sort_index()
# Out:
# income_cat
# 1     822
# 2    6581
# 3    7236
# 4    3639
# 5    2362
# Name: count, dtype: int64

# %%
housing["income_cat"].value_counts().sort_index().plot.bar(rot=0, grid=True)
plt.xlabel("Income category")
plt.ylabel("Number of districts")
plt.show()

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Create a splitter to generate 10 splits with 80% training and 20% test data
splitter = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)

# Create a list to store the splits
strat_splits = []

# Loop to generate 10 different train/test splits based on income category
for train_index, test_index in splitter.split(housing, housing["income_cat"]):
    strat_train_set_n = housing.iloc[train_index]
    strat_test_set_n = housing.iloc[test_index]
    strat_splits.append([strat_train_set_n, strat_test_set_n])

# Take the first split
strat_train_set, strat_test_set = strat_splits[0]

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13096    -122.42     37.80                52.0       3321.0          1115.0
# 14973    -118.38     34.14                40.0       1965.0           354.0
# 3785     -121.98     38.36                33.0       1083.0           217.0
# 14689    -117.11     33.75                17.0       4174.0           851.0
# 20507    -118.15     33.77                36.0       4366.0          1211.0
# ...          ...       ...                 ...          ...             ...
# 14207    -118.40     33.86                41.0       2237.0           597.0
# 13105    -119.31     36.32                23.0       2945.0           592.0
# 19301    -117.06     32.59                13.0       3920.0           775.0
# 19121    -118.40     34.06                37.0       3781.0           873.0
# 19888    -122.41     37.66                44.0        431.0           195.0
#
# ...

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3905     -121.95     37.11                21.0       2387.0           357.0
# 16821    -118.01     33.89                36.0       1589.0           265.0
# 2900     -118.18     33.74                30.0       5915.0          1750.0
# 7193     -122.48     37.74                52.0       2166.0           423.0
# 13928    -122.39     37.78                 5.0       1405.0           515.0
# ...          ...       ...                 ...          ...             ...
# 12369    -124.16     40.79                46.0       3042.0           597.0
# 8707     -119.01     35.39                29.0       1820.0           459.0
# 16634    -123.01     38.67                33.0        914.0           147.0
# 9779     -122.03     37.60                24.0       2077.0           383.0
# 3455     -117.12     32.74                52.0       1969.0           389.0
#
# ...

# %%
from sklearn.model_selection import train_test_split

strat_train_set, strat_test_set = train_test_split(
    housing, test_size=0.2, stratify=housing["income_cat"], random_state=42
)

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13096    -122.42     37.80                52.0       3321.0          1115.0
# 14973    -118.38     34.14                40.0       1965.0           354.0
# 3785     -121.98     38.36                33.0       1083.0           217.0
# 14689    -117.11     33.75                17.0       4174.0           851.0
# 20507    -118.15     33.77                36.0       4366.0          1211.0
# ...          ...       ...                 ...          ...             ...
# 14207    -118.40     33.86                41.0       2237.0           597.0
# 13105    -119.31     36.32                23.0       2945.0           592.0
# 19301    -117.06     32.59                13.0       3920.0           775.0
# 19121    -118.40     34.06                37.0       3781.0           873.0
# 19888    -122.41     37.66                44.0        431.0           195.0
#
# ...

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3905     -121.95     37.11                21.0       2387.0           357.0
# 16821    -118.01     33.89                36.0       1589.0           265.0
# 2900     -118.18     33.74                30.0       5915.0          1750.0
# 7193     -122.48     37.74                52.0       2166.0           423.0
# 13928    -122.39     37.78                 5.0       1405.0           515.0
# ...          ...       ...                 ...          ...             ...
# 12369    -124.16     40.79                46.0       3042.0           597.0
# 8707     -119.01     35.39                29.0       1820.0           459.0
# 16634    -123.01     38.67                33.0        914.0           147.0
# 9779     -122.03     37.60                24.0       2077.0           383.0
# 3455     -117.12     32.74                52.0       1969.0           389.0
#
# ...

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
# Out:
# income_cat
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: count, dtype: float64

# %%
#  Dropping the "income_cat" Column
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %% [markdown]
# ###### Explore and Visualize the Data to Gain Insights

# %%
# lets take a copy of the traing set
housing = strat_train_set.copy()
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13096    -122.42     37.80                52.0       3321.0          1115.0
# 14973    -118.38     34.14                40.0       1965.0           354.0
# 3785     -121.98     38.36                33.0       1083.0           217.0
# 14689    -117.11     33.75                17.0       4174.0           851.0
# 20507    -118.15     33.77                36.0       4366.0          1211.0
# ...          ...       ...                 ...          ...             ...
# 14207    -118.40     33.86                41.0       2237.0           597.0
# 13105    -119.31     36.32                23.0       2945.0           592.0
# 19301    -117.06     32.59                13.0       3920.0           775.0
# 19121    -118.40     34.06                37.0       3781.0           873.0
# 19888    -122.41     37.66                44.0        431.0           195.0
#
# ...

# %% [markdown]
# - Visualizing Geographical Data

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", grid=True)
plt.show()

# %%
# lest set alpha=0.2 to see the datapoint much clear way
housing.plot(kind="scatter", x="longitude", y="latitude", grid=True, alpha=0.2)
plt.show()

# %%
# lest look at housing prices
housing.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=housing["population"] / 100, label="population",
             c="median_house_value", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %% [markdown]
# - Look for Correlations

# %%
corr_matrix = housing.corr(numeric_only=True)
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924213           -0.102937     0.044558
# latitude            -0.924213  1.000000            0.005692    -0.036753
# housing_median_age  -0.102937  0.005692            1.000000    -0.361710
# total_rooms          0.044558 -0.036753           -0.361710     1.000000
# total_bedrooms       0.068210 -0.066391           -0.317978     0.930076
# population           0.104236 -0.115677           -0.301906     0.863967
# households           0.054261 -0.071604           -0.300075     0.916143
# median_income       -0.016542 -0.078137           -0.127043     0.197720
# median_house_value  -0.050859 -0.139584            0.102175     0.137455
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.068210    0.104236    0.054261      -0.016542
# latitude                 -0.066391   -0.115677   -0.071604      -0.078137
# ...

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688380
# total_rooms           0.137455
# housing_median_age    0.102175
# households            0.071426
# total_bedrooms        0.054635
# population           -0.020153
# longitude            -0.050859
# latitude             -0.139584
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
scatter_matrix(housing[attributes], figsize=(15, 10))
plt.show()

# %%
housing.plot(kind="scatter", x="median_income", y="median_house_value",alpha=0.1, grid=True)
plt.show()

# %% [markdown]
# ###### Experiment with Attribute Combinations

# %%
# create new attributes based on raw features
housing["rooms_per_house"] = housing["total_rooms"] / housing["households"]
housing["bedrooms_ratio"] = housing["total_bedrooms"] / housing["total_rooms"]
housing["people_per_house"] = housing["population"] / housing["households"]

# %%
corr_matrix = housing.corr(numeric_only=True)
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924213           -0.102937     0.044558
# latitude            -0.924213  1.000000            0.005692    -0.036753
# housing_median_age  -0.102937  0.005692            1.000000    -0.361710
# total_rooms          0.044558 -0.036753           -0.361710     1.000000
# total_bedrooms       0.068210 -0.066391           -0.317978     0.930076
# population           0.104236 -0.115677           -0.301906     0.863967
# households           0.054261 -0.071604           -0.300075     0.916143
# median_income       -0.016542 -0.078137           -0.127043     0.197720
# median_house_value  -0.050859 -0.139584            0.102175     0.137455
# rooms_per_house     -0.027899  0.108037           -0.153900     0.128631
# bedrooms_ratio       0.087802 -0.108871            0.139119    -0.183273
# people_per_house     0.024587 -0.026457            0.012771    -0.037702
#
# ...

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688380
# rooms_per_house       0.143663
# total_rooms           0.137455
# housing_median_age    0.102175
# households            0.071426
# total_bedrooms        0.054635
# population           -0.020153
# people_per_house     -0.038224
# longitude            -0.050859
# latitude             -0.139584
# bedrooms_ratio       -0.256397
# Name: median_house_value, dtype: float64

# %% [markdown]
# ###### Prepare the Data for Machine Learning Algorithms
