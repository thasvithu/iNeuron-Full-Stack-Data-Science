# %% [markdown]
# ## Breaking Down Linear Regression from Scratch

# %% [markdown]
# #### Why Do We Need Linear Regression?

# %% [markdown]
# Let’s begin by understanding why Linear Regression is useful in real-world scenarios. Imagine we have a dataset with two attributes: "Study Hours" (X) and "Scores" (Y).
#
# Here's a simplified version of the data:
#
# x = [1, 2, 3, 4]
#
# y = [3, 5, 7, 9]
#
#
#
# *Note*
#
# In this example, we’re using a small dataset for simplicity. Working with a smaller dataset helps focus on the core concept of Linear Regression. In real-world scenarios, datasets are typically larger and more complex, and drawing conclusions can become more challenging.

# %% [markdown]
# Now, let's visualize this dataset on a graph using the matplotlib library in Python:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4]
y = [3, 5, 7, 9]

# Plotting the data points
plt.plot(x , y, marker='o')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores")
plt.show()

# %% [markdown]
# When you plot the data, you will see that all the points align perfectly along a straight line. This indicates a linear relationship between the "Study Hours" and "Scores". However, keep in mind that in real-world data, perfect alignment like this is rare. Usually, data points will vary, resulting in some errors.

# %% [markdown]
# ###### The Equation of a Line: y = mx + c
# A line can be represented mathematically by the equation:
#
# $
#     y = mx + c
# $
#
# Where:
# - m is the slope of the line (how steep it is).
# - c is the intercept (where the line crosses the y-axis).
#
#
# Let’s calculate the slope (m) and intercept (c) manually using the points in our dataset.
#
# We'll use the points (x1, y1) = (1, 3) and (x2, y2) = (2, 5) to calculate the slope and intercept.

# %% [markdown]
# ###### Step 1: Calculate the Slope (m)
# The formula for the slope between two points is:
#
# m = (y2 - y1) / (x2 - x1)

# %%
x1 = 1
y1 = 3
x2 = 2
y2 = 5

#lets find the slope
m = (y2 - y1) / (x2 - x1)
print(f"Slope(m) is : {m}")
# Out:
# Slope(m) is : 2.0

# %% [markdown]
# ###### Step 2: Calculate the Intercept (c)
# To find the intercept c, we use the equation y = mx + c. Let's plug in the values of x1 = 1 and y1 = 3

# %%
#lets find the intercept using x1, y1
#y = mx + c
#c = y - m * x

x1 = 1
y1 = 3

c = y1 - m * x1
print(f"Intercept(c) is : {c}")
# Out:
# Intercept(c) is : 1.0

# %% [markdown]
# ###### Step 3: Making Predictions
# Now that we have the equation of the line, we can use it to predict the values of y for any given x.
#
# For example:
#
# Let’s predict the scores for study hours of 10, 15, and 50:

# %%
x_new = [10, 15, 50]

for i in x_new:
    y_pred = 2 * i + 1
    print(f"When study hours = {i}, the predicted score is: {y_pred}")
# Out:
# When study hours = 10, the predicted score is: 21
# When study hours = 15, the predicted score is: 31
# When study hours = 50, the predicted score is: 101

# %% [markdown]
# ###### What is a Model?
# You might be wondering: What exactly is a model?
#
# Don’t worry, the term model can sometimes seem complex, but in this context, it’s simply a mathematical equation. In our case, the equation y=2x+1 is the model. Using this equation, we can predict the output (scores) for any input (study hours).

# %% [markdown]
# ###### What is the Mean Error?
# It’s crucial to understand error in this context. Let’s take the first two points from our dataset:
#
# x1 = 1 and y1 = 3
#
# After building our model, if you input x = 1, the model will predic y = 3. In this case, there’s no error because the model predicted the actual value correctly.
#
# However, if the model predicts a value that differs from the actual value, that’s an error. And while a model might predict the correct value for some inputs, in the real world, it rarely happens consistently. In most cases, there will be some error in the predictions.

# %% [markdown]
# ###### What Happens in the Real World?
# In real-world scenarios, datasets aren’t as neat and perfectly aligned as the one we just used. When you plot real-world data, you’ll notice that the points won’t fall on a straight line. The data might have some "noise", meaning there will be discrepancies between the actual values and the predicted values.
#
# Because of this, predictions using a perfect line would likely be inaccurate. This is where Linear Regression becomes essential!

# %% [markdown]
# ###### How Linear Regression Helps
# Linear Regression helps by finding the best-fit line, which minimizes the errors between the predicted values and the actual data points. The algorithm will adjust the slope (m) and intercept (c) in such a way that the total error (difference between the actual and predicted values) is minimized.
#
# In future sections, we will explore techniques like Gradient Descent to optimize the model parameters (m and c) and minimize the error.

# %% [markdown]
# #### What is Linear Regression?
# Linear Regression is a supervised machine learning algorithm used to make predictions when there is a linear relationship between the variables in the dataset. In other words, if the data shows a linear trend, Linear Regression can be used to model and predict the outcomes.
#
# By now, I hope you have a solid understanding of Linear Regression and why it’s important

# %% [markdown]
# ##### What’s Next?
# In the next section, we will explore non-linear datasets and see how Linear Regression applies, even when the data doesn’t perfectly fit a straight line. Curious to dive deeper? Stay tuned as we continue this journey!

# %% [markdown]
# ###### Let’s Define Our New Dataset
# We will take our previous dataset with some changes
#
# "Study Hours" (X) and "Scores" (Y).
#
# x = [1, 2, 3, 4]
#
# y = [2, 5, 7, 12]

# %% [markdown]
# Now, let's visualize this dataset on a graph using the matplotlib library in Python:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4]
y = [2, 6, 7, 12]

# Plotting the data points
plt.plot(x , y, marker='o')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores")
plt.show()

# %% [markdown]
# Now, by looking at the graph, we can see that there’s non-linearity between the points. In this case, we can't draw a straight line through all the points. So, what do we do next? We apply Linear Regression.

# %% [markdown]
# #### Applying Linear Regression to Non-Linear Data

# %% [markdown]
# At this point, if we apply Linear Regression directly, we’re going to face a problem. The algorithm will try to find a straight line, but since the data doesn’t follow a straight line, the model will struggle. initially, it will start with m = 0 and c = 0. From here, it will try to draw a line.

# %% [markdown]
# So, let’s visualize what happens when we plot the line with m = 0 and c = 0:

# %%
# Initialize m and c to 0
m = 0
c = 0

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m=0, c=0)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# As you can see, with m = 0 and c = 0 the line drawn by the model doesn't fit well with the data. This highlights the challenge of applying Linear Regression to non-linear data. now what we have to do is as i said erlier Linear Regression fit-line by optimizing the error(reduse the error) by using Gradient Descient.

# %% [markdown]
# #### Now We Are Going to Dive Into the Mathematical Portion

# %% [markdown]
# Don’t worry—it’s the most interesting part! Let's now calculate the total error using MSE (Mean Squared Error).
#
#
# ##### Mean Squared Error (MSE)
# MSE is commonly used to find the error in regression tasks.
#
# The equation for MSE is:
#
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
#
# Where:
# - MSE: Mean Squared Error
# - n: Number of data points
# - yi: Actual value of the i-th data point
# - y^i : Predicted value of the i-th data point

# %% [markdown]
# Let’s calculate the total error when m = 0 and c = 0:

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (from m = 0, c = 0)
y_pred = [0, 0, 0, 0]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 58.25

# %% [markdown]
# Now we’ve calculated the total error 58.25 it is mean that fited line is so far from the data points if we do prediction with this error we will get aviosly wrong answer. In Linear Regression, the main aim is to reduce the error towards 0. so lets see how we can achive this using gradient desient

# %% [markdown]
# Next Step: Gradient Descent
#
# Now, we are going to dive into the heart of the process: Gradient Descent. Be patient, and let me make this process easier to understand.

# %% [markdown]
# #### Gradient Descent: The Optimization Algorithm
#
# In Linear Regression, the goal is to minimize the error (cost function) by finding the best values for m and c. Gradient Descent is an optimization algorithm that adjusts m and c iteratively to reduce the error.
#
# The process works as follows:
# 1. Start with initial values for m and c (e.g., 0).
# 2. Calculate the error (Mean Squared Error) for the current values.
# 3. Compute the gradients (∂J/∂m and ∂J/∂c) to determine the direction to move.
# 4. Update m and c using the formulas
#
# m = m - α . ∂J/∂m
#
# c = c - α . ∂J/∂c
#
# where α is the learning rate that controls how much m and c change in each iteration
#
# 5. Repeat steps 2–4 until the error converges to a minimum value.
#
# By iteratively updating m and c, Gradient Descent ensures that the model finds the optimal line that minimizes the error.

# %% [markdown]
# Now Let's take drivatives of error(MSE) with respect to m and c to find new m and c values.

# %% [markdown]
# Lets take drivative with respect to m
#
# why we are doing this is now we have a large error to m = 0 right, so in drivative what we are doing is we change m a little bit and seeing how error changes and which will give us new m as well
#
# here see how to do this, and we usually denoted MSE as J
#
# $$ \frac{dJ}{dm} = \frac{1}{n} \sum_{i=1}^{n} -2x_i(y_i - \hat{y}_i)$$
#
#  this equation tells you if m changes a littel bit how error will change, i hopw you got the point
#
#
#  Lest take drivative with respect to c
#
#  $$ \frac{dJ}{dc} = \frac{1}{n} \sum_{i=1}^{n} -2(y_i - \hat{y}_i)$$
#
#  this equations tells you if c changes a littel bit how error will chaneg
#
#
#  and here i did not show you each steps in derivatives i just show you the final one(output)

# %% [markdown]
# so, now we have drivatices of MSE with respect to m and c right
#
# Now lest apply the m and c values
#
# For dJ/dm
#
#  $$ \frac{dJ}{dm} = -\frac{2}{4} \sum_{i=1}^{4}x_i \hat{y}_i$$
#
# Substitute x=[1,2,3,4] and y=[2,6,7,12]
# $$ \frac{dJ}{dm} = -\frac{2}{4}(1.2 + 2.6 + 3.7 + 4.12)$$
# $$ \frac{dJ}{dm} = -\frac{2}{4}(2 + 12 + 21 + 48)$$
# $$ \frac{dJ}{dm} = -\frac{2}{4}.83$$
# $$ \frac{dJ}{dm} = -\frac{166}{4} = -41.5$$
#
#
# For dJ/dc
#  $$ \frac{dJ}{dc} = \frac{1}{4} \sum_{i=1}^{n}y_i$$
#
# Substitute y=[2,6,7,12]
# $$ \frac{dJ}{dc} = -\frac{2}{4}(2 + 6 + 7 + 12)$$
# $$ \frac{dJ}{dc} = -\frac{2}{4}.27$$
# $$ \frac{dJ}{dm} = -\frac{54}{4} = -13.5$$

# %% [markdown]
# so finally we find the gradients lets find the new m and c values, usually we give  α = 0.01 (learning rate)
#
# ```
# m = m - α . ∂J/∂m
# m = 0 - 0.01 * (-41.5)
# m = 0 + 0.415
# m = 0.415
# ```
#
# ```
# c = c - α . ∂J/∂c
# c = 0 - 0.01 * (-13.5)
# c = 0 + 0.135
# c = 0.135
# ```
#
# so this is our new m and c values, having this the model again try to predit output to x and ahain find MSE and it will do derivative with respect to new m and c and it will find another m and c values up to erros becoms touch global minimum point, if model touch gloabal minimum poit that is the best line of this dataset then model stops to find new line.

# %% [markdown]
# using new m = 0.415 and c = 0.135 let's predict to the input x

# %%
# Initialize m and c to 0
m = 0.415
c = 0.135

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m=0.415, c=0.135)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# wow, now you can see the changes in predicted line, it is moving towards the datapoints, and we calculate the error and compare with previous

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (from m = 0.415, c = 0.135)
y_pred = [0.55, 0.965, 1.38, 1.795]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 40.79503750000001

# %% [markdown]
# our previous error was 58.25 now our new error is 40.79, so can you realize the power of gradient desient and derivative something cool right, so until this point you get some ideas right how achually model update the new m and c values and how to reduse the error
#
# now we will  take derivaties to MSE with respect to current m and c to find the new m and c values to rediuse the error
#
# here after iam not going to going show the derivatie steps you can follow the previous m and c updates steps, here also we are doing the same thing so iam show you just calculated m and c

# %% [markdown]
# after updating m and c the new m and c values
# m=0.761
# c=0.24655
#
# if you want you can calculte it mannually for making this article more simply thats why i did not include more calculations parts

# %% [markdown]
# using new m = 0.761 and c = 0.24655 let's predict to the input x

# %%
# Initialize m and c to 0
m = 0.761
c = 0.24655

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m=0.761, c=0.24655)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# wow, now you can see the changes in predicted line, it is moving towards the datapoints, and we calculate the error and compare with previous

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (from m = 0.761, c = 0.24655)
y_pred = [1.00755, 1.76855, 2.52955, 3.29055]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 28.6823921525

# %% [markdown]
# so as we going forward we decrees our error right :)
#
# Lest calculte our new m and c values
#
# m=1.0495
#
# c=0.3386

# %% [markdown]
# using new m =1.0495 and c = 0.3386 let's predict to the input x

# %%
# Initialize m and c to 0
m = 1.0495
c = 0.3386

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m=1.0495, c=0.3386)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# so line going towards to datapoints
#
# Lest find the error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (fromm=1.0495, c=0.3386)
y_pred = [1.3881000000000001, 2.4376, 3.4871000000000003, 4.5366]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 20.276980334999998

# %% [markdown]
# previous error 28 now 20

# %% [markdown]
# Lest find new m and c values

# %% [markdown]
# so new m = 1.2901 c = 0.4144 Let's predict to the input x

# %%
# Initialize m and c to 0
m =  1.2901
c = 0.4144

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m=1.2901, c=0.4144)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %%
y_pred
# Out:
# [1.7045, 2.9946, 4.2847, 5.5748]

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m=1.2901, c=0.4144)
y_pred = [1.7045, 2.9946, 4.2847, 5.5748]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 14.443949635000001

# %% [markdown]
# Lest find our new m and c values

# %% [markdown]
# new m = 1.4909 c = 0.4766 Let's predict to the input x

# %%
# Initialize m and c to 0
m = 1.4909
c = 0.4766

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 1.4909, c=0.4766)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 1.4909, c=0.4766)
y_pred = [1.9674999999999998, 3.4583999999999997, 4.9493, 6.4402]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 10.394383335

# %% [markdown]
# Lest find new m and c values
#
# using new m =1.6534 and c = 0.5275 let's predict to the input x

# %%
# Initialize m and c to 0
m = 1.6534
c = 0.5275

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 1.6534, c= 0.5275)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 1.6534, c=0.4766)
y_pred = [2.13, 3.7834, 5.436800000000001, 7.0902]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 7.869986459999998

# %% [markdown]
# Lest find new m and c values
#
# using new m =1.7940 and c = 0.5693 let's predict to the input x

# %%
# Initialize m and c to 0
m = 1.7940
c = 0.5693

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 1.7940, c=0.5693)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 1.7940, c=0.5693)
y_pred = [2.3633, 4.1573, 5.9513, 7.7453]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 5.68244349

# %% [markdown]
# Lest find new m and c values
#
# using new m =1.9114 and c = 0.6032 let's predict to the input x

# %%
# Initialize m and c to 0
m = 1.9114
c = 0.6032

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 1.9114, c=0.6032)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 1.9114, c=0.6032)
y_pred = [2.5145999999999997, 4.426, 6.3374, 8.2488]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 4.313207340000002

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.0096 and c = 0.6306 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.0096
c = 0.6306

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.0096, c=0.6032)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.0096, c=0.6032)
y_pred = [2.6402, 4.6498, 6.6594, 8.668999999999999]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 3.3611163600000022

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.0916 and c = 0.6525 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.0916
c = 0.6525

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.0916, c=0.6525)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %%
y_pred
# Out:
# [2.7441, 4.8357, 6.927300000000001, 9.0189]

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.0916, c=0.6525)
y_pred = [2.7441, 4.8357, 6.927300000000001, 9.0189]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 2.7003804499999995

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.1602 and c = 0.6699 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.1602
c = 0.6699

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.1602, c= 0.6699)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.1602, c= 0.6699)
y_pred = [2.8301000000000003, 4.9903, 7.150500000000001, 9.3107]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 2.2408862099999993

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.2157 and c = 0.6829 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.2157
c = 0.6829

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.2157, c= 0.6829)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %%
y_pred
# Out:
# [2.8986, 5.1143, 7.33, 9.5457]

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.2157, c= 0.6829)
y_pred = [2.8986, 5.1143, 7.33, 9.5457]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.931108735

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.2642 and c = 0.6935 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.2642
c = 0.6935

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.2642, c= 0.6935)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.2642, c= 0.6935)
y_pred = [2.9577, 5.221900000000001, 7.4861, 9.750300000000001]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.7050180499999987

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.3049 and c = 0.7014  let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.3049
c = 0.7014

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.3049, c= 0.7014)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.3049, c= 0.7014)
y_pred = [3.0063, 5.3111999999999995, 7.616099999999999, 9.921]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.5472263350000006

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.3391 and c = 0.7071 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.3391
c = 0.7071

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.3391, c= 0.7071)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.3391, c= 0.7071)
y_pred = [3.0462000000000002, 5.3853, 7.7244, 10.063500000000001]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.436794534999999

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.3679 and c = 0.7110 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.3679
c = 0.7110

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.3679, c= 0.7110)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.3679, c= 0.7110)
y_pred = [3.0789, 5.4468000000000005, 7.8147, 10.1826]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.3591835749999994

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.3922 and c = 0.7134 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.3922
c = 0.7134

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.3679, c= 0.7110)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.3679, c= 0.7110)
y_pred = [3.1056, 5.4978, 7.89, 10.2822]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.3043732600000002

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.4127 and c = 0.7145 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.4127
c = 0.7145

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.3679, c= 0.7110)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.3679, c= 0.7110)
y_pred = [3.1272, 5.5399, 7.9526, 10.3653]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.2654906750000006

# %% [markdown]
# Lest find new m and c values
#
# using new m =2.4301 and c = 0.7146 let's predict to the input x

# %%
# Initialize m and c to 0
m = 2.4301
c = 0.7146

# Generate the predicted values using the equation y = mx + c
y_pred = [m * xi + c for xi in x] # here x means our dataset feature

# Plotting the data points and the predicted line
plt.plot(x, y, marker='o', label='Data points')
plt.plot(x, y_pred, label='Predicted Line (m= 2.3679, c= 0.7110)', linestyle='--')
plt.xlabel("Study Hours (X)")
plt.ylabel("Scores (Y)")
plt.title("Study Hours vs Scores with Predicted Line")
plt.legend()
plt.show()

# %% [markdown]
# Current Error

# %%
import numpy as np

# Actual values
y = [2, 6, 7, 12]

# Predicted values (m= 2.3679, c= 0.7110)
y_pred = [3.1447, 5.5748, 8.004900000000001, 10.435]

# Function to calculate MSE
def find_mse(n, y_act, y_pred):
    return np.sum((np.array(y_act) - np.array(y_pred)) ** 2) / n

# Calculating MSE
mse = find_mse(4, y, y_pred)
print(f"MSE is: {mse}")
# Out:
# MSE is: 1.2375455350000002
